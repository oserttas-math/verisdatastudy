# %%
# %matplotlib inline
import os
import glob
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import json
from verispy import VERIS
import pprint
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap
from chart_studio.plotly import plot, iplot
import chart_studio

# %%
with open('vcdb.json') as data_file:    
    data = json.load(data_file)

# %%
df = pd.json_normalize(data)
df.shape
# Out:
# (8587, 173)

# %%
df.head()
# Out:
#                             incident_id  \
# 0  0008DADB-E83D-4278-A19A-CEE01610CF43
# 1  000D403E-2DC9-4EA7-9294-BD3938D1C3C7
# 2  0012CC25-9167-40D8-8FE3-3D0DFD8FB6BB
# 3  00163384-B4D7-46D5-9E6F-543DFB00F598
# 4  00163384-B4D7-46D5-9E6F-543DFB00F598
#
#                                            reference  \
# 0  http://healthitsecurity.com/2014/12/11/laptop-...
# 1  http://www.njbiz.com/article/20140811/NJBIZ01/...
# 2  http://www.publicservice.co.uk/news_story.asp?...
# 3       http://vcdb.org/pdf/va-security-feb-2014.pdf
# 4       http://vcdb.org/pdf/va-security-feb-2014.pdf
#
#                                              summary source_id  \
# 0  Patients at an Oregon healthcare facility were...      vcdb
# 1  Jersey City Medical Center said a computer dis...      vcdb
# 2  Sensitive information belonging to jobseekers ...      vcdb
# 3  Veteran A returned a hard copy written prescri...      vcdb
# 4  Veteran A returned a hard copy written prescri...      vcdb
#
#   security_incident schema_version impact.overall_rating  \
# 0         Confirmed          1.3.4               Unknown
# 1         Confirmed          1.3.4               Unknown
# 2         Confirmed          1.3.4               Unknown
# 3         Confirmed          1.3.4                   NaN
# 4         Confirmed          1.3.4                   NaN
#
#   attribute.availability.variety attribute.confidentiality.data_victim  \
# 0                         [Loss]                             [Patient]
# 1                         [Loss]                             [Patient]
# 2                            NaN                            [Customer]
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#   attribute.confidentiality.state  ... value_chain.development.variety  \
# 0            [Stored unencrypted]  ...                             NaN
# 1            [Stored unencrypted]  ...                             NaN
# 2            [Stored unencrypted]  ...                             NaN
# 3                             NaN  ...                             NaN
# 4                             NaN  ...                             NaN
#
#   value_chain.targeting.variety value_chain.distribution.variety  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#   value_chain.development.notes value_chain.non-distribution services.notes  \
# 0                           NaN                                         NaN
# 1                           NaN                                         NaN
# 2                           NaN                                         NaN
# 3                           NaN                                         NaN
# 4                           NaN                                         NaN
#
#   value_chain.non-distribution services.variety  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   value_chain.distribution.notes value_chain.targeting.notes asset.role  \
# 0                            NaN                         NaN        NaN
# 1                            NaN                         NaN        NaN
# 2                            NaN                         NaN        NaN
# 3                            NaN                         NaN        NaN
# 4                            NaN                         NaN        NaN
#
#   value_chain.money laundering.variety
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 173 columns]
